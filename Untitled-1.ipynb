# %%
import pandas
import os
import json
path_file_ransomware=os.path.join(os.getcwd(),"data","lifecycle_only_enterprise","ransomware.xlsx")

# %%
file_ransomeware=pandas.read_excel(path_file_ransomware)

# %%
file_ransomeware
# Out:
#    Tactic Tactic Name Technique  Sub Technique  \
# 0  TA0002   Execution     T1059          0.001
# 1  TA0040      Impact     T1486            NaN
# 2  TA0007   Discovery     T1083            NaN
# 3  TA0040      Impact     T1490            NaN
# 4  TA0002   Execution     T1106            NaN
# 5  TA0007   Discovery     T1135            NaN
# 6  TA0007   Discovery     T1057            NaN
# 7  TA0007   Discovery     T1082            NaN
# 8  TA0002   Execution     T1047            NaN
#
#                                   Technique Name  \
# 0  Command and Scripting Interpreter: PowerShell
# 1                      Data Encrypted for Impact
# 2                   File and Directory Discovery
# 3                        Inhibit System Recovery
# 4                                     Native API
# 5                        Network Share Discovery
# 6                              Process Discovery
# 7                   System Information Discovery
# ...
